# %%
# Import dependencies
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.linear_model import LinearRegression

# %%
# Read in the data
url_climate_data_complete = 'https://raw.githubusercontent.com/Ricardolpz99/Turn-Green/main/Database/climate_data_complete_copy.csv'
df = pd.read_csv(url_climate_data_complete)
df.head()
# Out:
#    Unnamed: 0  Entity Code  Year  Annual CO2 emissions (per capita)  \
# 0           0  Africa  NaN  1965                             0.6750
# 1           1  Africa  NaN  1966                             0.6814
# 2           2  Africa  NaN  1967                             0.7124
# 3           3  Africa  NaN  1968                             0.7541
# 4           4  Africa  NaN  1969                             0.7938
#
#    Renewables (% sub energy)
# 0                      5.526
# 1                      5.862
# 2                      6.069
# 3                      6.730
# 4                      7.669

# %%
# Rename Colums Annual CO2 emissions (per capita) and Renewables (% sub energy)
df= df.rename(columns={"Annual CO2 emissions (per capita)":"Emissions","Renewables (% sub energy)":"Renewables"})

# %%
# Compare actual values of the columns
plt.figure(figsize=(20,20))
plt.scatter(df.Emissions, df.Renewables)
plt.xlabel('Renewables')
plt.ylabel('Emissions')
plt.show()

# %%
#formats the data to meet the requirements of the Scikit-learn library
X = df.Renewables.values.reshape(-1, 1)

# %%
#examine the first five entries in 
X[:5]
# Out:
# array([[5.526],
#        [5.862],
#        [6.069],
#        [6.73 ],
#        [7.669]])

# %%
# The shape of x , with a single feature
X.shape
# Out:
# (4367, 1)

# %%
# Assing Target variable
y = df.Emissions

# %%
# Create an instance of linear regression model
model = LinearRegression()

# %%
# fitting step
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Generate predictions
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (4367,)

# %%
# Print overall trend
plt.figure(figsize=(20,20))
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
# Obtain the coefficient of determination by calling the model with the score() function, then print the coefficient:
r_sq = model.score(X, y)
print('coefficient of determination:', r_sq)

# Print the Intercept:
print('intercept:', model.intercept_)

# Print the Slope:
print('slope:', model.coef_) 

# Predict a Response and print it:
y_pred = model.predict(X)
print('Predicted response:', y_pred, sep='\n')
# Out:
# coefficient of determination: 0.0356434102684261
# intercept: 9.34879796331495
# slope: [-0.12584023]
# Predicted response:
# [8.65340488 8.61112256 8.58507363 ... 7.96732397 7.9095633  7.76912561]
