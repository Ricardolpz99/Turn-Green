# %%
# Add the Pandas dependency.
import pandas as pd
import numpy as np

# %%
url_Climate_data_complete = 'https://raw.githubusercontent.com/Ricardolpz99/Turn-Green/main/Database/Clean/Climate_data_complete_(no_null_values).csv'
Climate_data_complete_df = pd.read_csv(url_Climate_data_complete)

# %%
Climate_data_complete_df.head()
# Out:
#    Unnamed: 0  Entity Code  Year  Annual CO2 emissions (per capita)  \
# 0           0  Africa  AFR  1965                             0.6750
# 1           1  Africa  AFR  1966                             0.6814
# 2           2  Africa  AFR  1967                             0.7124
# 3           3  Africa  AFR  1968                             0.7541
# 4           4  Africa  AFR  1969                             0.7938
#
#    Renewables (% sub energy)
# 0                      5.526
# 1                      5.862
# 2                      6.069
# 3                      6.730
# 4                      7.669

# %%
Climate_data_complete_df.drop(['Unnamed: 0'], axis=1)
# Out:
#       Entity      Code  Year  Annual CO2 emissions (per capita)  \
# 0     Africa       AFR  1965                             0.6750
# 1     Africa       AFR  1966                             0.6814
# 2     Africa       AFR  1967                             0.7124
# 3     Africa       AFR  1968                             0.7541
# 4     Africa       AFR  1969                             0.7938
# ...      ...       ...   ...                                ...
# 3985   World  OWID_WRL  2016                             4.7496
# 3986   World  OWID_WRL  2017                             4.7595
# 3987   World  OWID_WRL  2018                             4.8022
# 3988   World  OWID_WRL  2019                             4.7582
# 3989   World  OWID_WRL  2020                             4.4654
#
#       Renewables (% sub energy)
# 0                         5.526
# 1                         5.862
# 2                         6.069
# 3                         6.730
# ...

# %%
url_Climate_data_complete_generated = 'https://raw.githubusercontent.com/Ricardolpz99/Turn-Green/main/Database/Clean/Climate_data_complete_generated.csv'
Climate_data_complete_generated_df=pd.read_csv(url_Climate_data_complete_generated)

# %%
Climate_data_complete_generated_df.drop(['Unnamed: 0'], axis=1)
# Out:
#       Entity      Code  Year  Annual CO2 emissions (per capita)  \
# 0     Africa       AFR  2000                             1.0936
# 1     Africa       AFR  2001                             1.0645
# 2     Africa       AFR  2002                             1.0489
# 3     Africa       AFR  2003                             1.1094
# 4     Africa       AFR  2004                             1.1603
# ...      ...       ...   ...                                ...
# 1200   World  OWID_WRL  2016                             4.7496
# 1201   World  OWID_WRL  2017                             4.7595
# 1202   World  OWID_WRL  2018                             4.8022
# 1203   World  OWID_WRL  2019                             4.7582
# 1204   World  OWID_WRL  2020                             4.4654
#
#       Solar Generation - TWh  Wind Generation - TWh  Hydro Generation - TWh  \
# 0                   0.011941               0.175500               75.245817
# ...

# %%
Climate_data_complete_generated_df.head(60)
# Out:
#     Unnamed: 0     Entity Code  Year  Annual CO2 emissions (per capita)  \
# 0           35     Africa  AFR  2000                             1.0936
# 1           36     Africa  AFR  2001                             1.0645
# 2           37     Africa  AFR  2002                             1.0489
# 3           38     Africa  AFR  2003                             1.1094
# 4           39     Africa  AFR  2004                             1.1603
# 5           40     Africa  AFR  2005                             1.1547
# 6           41     Africa  AFR  2006                             1.1613
# 7           42     Africa  AFR  2007                             1.1763
# 8           43     Africa  AFR  2008                             1.1968
# 9           44     Africa  AFR  2009                             1.1762
# 10          45     Africa  AFR  2010                             1.1725
# 11          46     Africa  AFR  2011                             1.1809
# ...

# %%
# Out:
#            Entity Code  Year  Annual CO2 emissions (per capita)  \
# 0     Afghanistan  AFG  2000                             0.0365
# 1     Afghanistan  AFG  2001                             0.0369
# 2     Afghanistan  AFG  2002                             0.0465
# 3     Afghanistan  AFG  2003                             0.0501
# 4     Afghanistan  AFG  2004                             0.0360
# ...           ...  ...   ...                                ...
# 6083     Zimbabwe  ZWE  2016                             0.7653
# 6084     Zimbabwe  ZWE  2017                             0.6730
# 6085     Zimbabwe  ZWE  2018                             0.8210
# 6086     Zimbabwe  ZWE  2019                             0.7476
# 6087     Zimbabwe  ZWE  2020                             0.7086
#
#       Renewable electricity per capita (kWh)
# 0                                     14.918
# 1                                     23.141
# 2                                     24.778
# ...

# %%
Climate_data_all_variables_df = pd.merge(Climate_data_complete_df, Climate_data_complete_generated_df)

# %%
Climate_data_all_variables_df.head(60)
# Out:
#     Unnamed: 0     Entity Code  Year  Annual CO2 emissions (per capita)  \
# 0           35     Africa  AFR  2000                             1.0936
# 1           36     Africa  AFR  2001                             1.0645
# 2           37     Africa  AFR  2002                             1.0489
# 3           38     Africa  AFR  2003                             1.1094
# 4           39     Africa  AFR  2004                             1.1603
# 5           40     Africa  AFR  2005                             1.1547
# 6           41     Africa  AFR  2006                             1.1613
# 7           42     Africa  AFR  2007                             1.1763
# 8           43     Africa  AFR  2008                             1.1968
# 9           44     Africa  AFR  2009                             1.1762
# 10          45     Africa  AFR  2010                             1.1725
# 11          46     Africa  AFR  2011                             1.1809
# ...

# %%
Climate_data_all_variables_df.drop(['Unnamed: 0'], axis=1)
# Out:
#       Entity Code  Year  Annual CO2 emissions (per capita)  \
# 0     Africa  AFR  2000                             1.0936
# 1     Africa  AFR  2001                             1.0645
# 2     Africa  AFR  2002                             1.0489
# 3     Africa  AFR  2003                             1.1094
# 4     Africa  AFR  2004                             1.1603
# ..       ...  ...   ...                                ...
# 454  Romania  ROU  2016                             3.7458
# 455  Romania  ROU  2017                             3.9281
# 456  Romania  ROU  2018                             3.9787
# 457  Romania  ROU  2019                             3.8651
# 458  Romania  ROU  2020                             3.7154
#
#      Renewables (% sub energy)  Solar Generation - TWh  Wind Generation - TWh  \
# 0                        6.759                0.011941               0.175500
# 1                        6.982                0.014960               0.415580
# ...

# %%
# Out:
#     Unnamed: 0_x     Entity Code  Year  Annual CO2 emissions (per capita)  \
# 0             21     Africa  AFR  2000                             1.0936
# 1             22     Africa  AFR  2001                             1.0645
# 2             23     Africa  AFR  2002                             1.0489
# 3             24     Africa  AFR  2003                             1.1094
# 4             25     Africa  AFR  2004                             1.1603
# 5             26     Africa  AFR  2005                             1.1547
# 6             27     Africa  AFR  2006                             1.1613
# 7             28     Africa  AFR  2007                             1.1763
# 8             29     Africa  AFR  2008                             1.1968
# 9             30     Africa  AFR  2009                             1.1762
# 10            31     Africa  AFR  2010                             1.1725
# 11            32     Africa  AFR  2011                             1.1809
# ...

# %%
# Out:
#       Entity Code  Year  Annual CO2 emissions (per capita)  \
# 0     Africa  AFR  2000                             1.0936
# 1     Africa  AFR  2001                             1.0645
# 2     Africa  AFR  2002                             1.0489
# 3     Africa  AFR  2003                             1.1094
# 4     Africa  AFR  2004                             1.1603
# ..       ...  ...   ...                                ...
# 453  Romania  ROU  2016                             3.7458
# 454  Romania  ROU  2017                             3.9281
# 455  Romania  ROU  2018                             3.9787
# 456  Romania  ROU  2019                             3.8651
# 457  Romania  ROU  2020                             3.7154
#
#      Renewable electricity per capita (kWh)  Renewables (% sub energy)  \
# 0                                    95.341                      6.759
# 1                                   101.444                      6.982
# ...

# %%
# Out:
#       Entity Code  Year  Annual CO2 emissions (per capita)  \
# 0     Africa  AFR  2000                             1.0936
# 1     Africa  AFR  2001                             1.0645
# 2     Africa  AFR  2002                             1.0489
# 3     Africa  AFR  2003                             1.1094
# 4     Africa  AFR  2004                             1.1603
# ..       ...  ...   ...                                ...
# 453  Romania  ROU  2016                             3.7458
# 454  Romania  ROU  2017                             3.9281
# 455  Romania  ROU  2018                             3.9787
# 456  Romania  ROU  2019                             3.8651
# 457  Romania  ROU  2020                             3.7154
#
#      Renewable electricity per capita (kWh)  Renewables (% sub energy)  \
# 0                                    95.341                      6.759
# 1                                   101.444                      6.982
# ...

# %%
Climate_data_all_variables_df.to_csv('Climate_data_2_variables.csv')
