# %%
# Import dependencies
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib import style
import os
from sklearn.linear_model import LinearRegression

# %%
# Read in the data
url_climate_data_complete = 'https://raw.githubusercontent.com/Ricardolpz99/Turn-Green/main/Database/Clean/Climate_data_all_variables.csv'
df = pd.read_csv(url_climate_data_complete)
df.head()
# Out:
#    Entity Code  Year  Annual CO2 emissions (per capita)  \
# 0  Africa  AFR  2000                             1.0936
# 1  Africa  AFR  2001                             1.0645
# 2  Africa  AFR  2002                             1.0489
# 3  Africa  AFR  2003                             1.1094
# 4  Africa  AFR  2004                             1.1603
#
#    Renewable electricity per capita (kWh)  Renewables (% sub energy)  \
# 0                                  95.341                      6.759
# 1                                 101.444                      6.982
# 2                                 101.457                      7.219
# 3                                  97.575                      6.703
# 4                                 101.360                      6.612
#
#    Solar Generation - TWh  Wind Generation - TWh  Hydro Generation - TWh  \
# 0                0.011941               0.175500               75.245817
# 1                0.014960               0.415580               80.864115
# 2                0.017871               0.443584               85.181468
# 3                0.021329               0.535599               82.872601
# 4                0.025761               0.768281               87.405469
#
#    Geo Biomass Other - TWh
# 0                 2.269063
# 1                 2.335353
# 2                 2.286400
# 3                 2.622400
# 4                 2.978850

# %%
# df = df.loc[df ['Entity'] == 'Portugal']
# df

# %%
# Rename Colums Annual CO2 emissions (per capita) and Renewables (% sub energy)
df= df.rename(columns={"Annual CO2 emissions (per capita)":"Emissions","Renewables (% sub energy)":"Renewables","Renewable electricity per capita (kWh)": "Renewable per capita","Solar Generation - TWh": "Solar Generation","Wind Generation - TWh": "Wind Generation","Hydro Generation - TWh": "Hydro Generation","Geo Biomass Other - TWh": "Geo Biomass Other"})
df
# Out:
#       Entity Code  Year  Emissions  Renewable per capita  Renewables  \
# 0     Africa  AFR  2000     1.0936                95.341       6.759
# 1     Africa  AFR  2001     1.0645               101.444       6.982
# 2     Africa  AFR  2002     1.0489               101.457       7.219
# 3     Africa  AFR  2003     1.1094                97.575       6.703
# 4     Africa  AFR  2004     1.1603               101.360       6.612
# ..       ...  ...   ...        ...                   ...         ...
# 453  Romania  ROU  2016     3.7458              1362.377      17.975
# 454  Romania  ROU  2017     3.9281              1235.883      15.801
# 455  Romania  ROU  2018     3.9787              1342.656      16.634
# 456  Romania  ROU  2019     3.8651              1271.911      15.962
# 457  Romania  ROU  2020     3.7154              1279.260      16.228
#
#      Solar Generation  Wind Generation  Hydro Generation  Geo Biomass Other
# 0            0.011941         0.175500         75.245817           2.269063
# 1            0.014960         0.415580         80.864115           2.335353
# 2            0.017871         0.443584         85.181468           2.286400
# 3            0.021329         0.535599         82.872601           2.622400
# 4            0.025761         0.768281         87.405469           2.978850
# ..                ...              ...               ...                ...
# 453          1.820000         6.590000         18.028000           0.531000
# 454          1.856000         7.407000         14.494000           0.525168
# 455          1.771000         6.322000         17.663900           0.437130
# 456          1.778000         6.773000         15.580921           0.504144
# 457          1.703000         6.955000         15.087386           0.575069
#
# [458 rows x 10 columns]

# %%
# # Compare actual values of the columns
# plt.figure(figsize=(20,20))
# plt.scatter(americas_df.Emissions, americas_df.Renewables)
# plt.xlabel('Renewables')
# plt.ylabel('Emissions')
# plt.show()

# %%
# Def input variable
X = df[['Renewables', 'Renewable per capita','Solar Generation', 'Wind Generation','Hydro Generation', 'Geo Biomass Other']]

# %%
# #formats the data to meet the requirements of the Scikit-learn library
# X = americas_df.Renewables.values.reshape(-1, 1)

# %%
id_df =df[['Entity', 'Code','Year','Emissions']]

# %%
#examine the first five entries in 
X[:5]
# Out:
#    Renewables  Renewable per capita  Solar Generation  Wind Generation  \
# 0       6.759                95.341          0.011941         0.175500
# 1       6.982               101.444          0.014960         0.415580
# 2       7.219               101.457          0.017871         0.443584
# 3       6.703                97.575          0.021329         0.535599
# 4       6.612               101.360          0.025761         0.768281
#
#    Hydro Generation  Geo Biomass Other
# 0         75.245817           2.269063
# 1         80.864115           2.335353
# 2         85.181468           2.286400
# 3         82.872601           2.622400
# 4         87.405469           2.978850

# %%
# The shape of x , with a single feature
X.shape
# Out:
# (458, 6)

# %%
# Assing Target variable
y = df.Emissions

# %%
# Create an instance of linear regression model
model = LinearRegression()

# %%
# fitting step
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Generate predictions
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (458,)

# %%
# # Print overall trend
# plt.figure(figsize=(20,20))
# plt.scatter(X, y)
# plt.plot(X, y_pred, color='red')
# plt.xlabel('Renewables %')
# plt.ylabel('Emissions')
# plt.show()

# %%
# Obtain the coefficient of determination by calling the model with the score() function, then print the coefficient:
r_sq = model.score(X, y)
print('coefficient of determination:', r_sq)

# Print the Intercept:
print('intercept:', model.intercept_)

# Print the Slope:
print('slope:', model.coef_) 

# Predict a Response and print it:
y_pred = model.predict(X)
print('Predicted response:', y_pred, sep='\n')
# Out:
# coefficient of determination: 0.3301253119132972
# intercept: 9.059330278445938
# slope: [-0.30550059  0.00091581  0.01081567 -0.0159797   0.0018386   0.0243075 ]
# Predicted response:
# [ 7.27259278  7.21819271  7.15213295  7.30870535  7.35330053  7.3542358
#   7.34083226  7.35519304  7.44318492  7.44040869  7.37757358  7.33947515
#   7.41099725  7.35225737  7.32035977  7.30712692  7.3456809   7.25262988
#   7.16389484  7.04007982  6.71954332  5.97701605  6.53949735  5.70561117
#   4.87274554  4.69357222  5.27350641  5.88587867  5.80693167  5.69008628
#   6.26574295  6.36339289  6.02898309  5.99125369  6.06022618  6.28924599
#   6.18730662  6.09747545  6.06864315  6.25118386  5.98361501  5.96483963
#   5.6746726   5.7704025   8.62823116  8.67537008  8.732001    8.75139746
# 0      0       6.759                95.341          0.011941         0.175500
# 1      1       6.982               101.444          0.014960         0.415580
# 2      2       7.219               101.457          0.017871         0.443584
# 3      3       6.703                97.575          0.021329         0.535599
# 4      4       6.612               101.360          0.025761         0.768281
#
#    Hydro Generation  Geo Biomass Other
# 0         75.245817           2.269063
# 1         80.864115           2.335353
# 2         85.181468           2.286400
# 3         82.872601           2.622400
# 4         87.405469           2.978850

# %%
# Drop a Pandas Dataframe index with `.reset_index()
X = X.reset_index(drop=True)
print(X.head())
# Out:
#    index  Renewables  Renewable per capita  Solar Generation  Wind Generation  \
# 0      0       6.759                95.341          0.011941         0.175500
# 1      1       6.982               101.444          0.014960         0.415580
# 2      2       7.219               101.457          0.017871         0.443584
# 3      3       6.703                97.575          0.021329         0.535599
# 4      4       6.612               101.360          0.025761         0.768281
#
#    Hydro Generation  Geo Biomass Other
# 0         75.245817           2.269063
# 1         80.864115           2.335353
# 2         85.181468           2.286400
# 3         82.872601           2.622400
# 4         87.405469           2.978850

# %%
#Drop Index

X= X.drop(columns= ['index'])

# %%
#Join Entity, code, year, emissions columns to predictions
predictions_df = id_df.join(predictions_df)

# %%
#Join predictions to input data
final_df = predictions_df.join(X)
final_df
# Out:
#       Entity Code  Year  Emissions  Predictions  Renewables  \
# 0     Africa  AFR  2000     1.0936     7.272593       6.759
# 1     Africa  AFR  2001     1.0645     7.218193       6.982
# 2     Africa  AFR  2002     1.0489     7.152133       7.219
# 3     Africa  AFR  2003     1.1094     7.308705       6.703
# 4     Africa  AFR  2004     1.1603     7.353301       6.612
# ..       ...  ...   ...        ...          ...         ...
# 453  Romania  ROU  2016     3.7458     4.776062      17.975
# 454  Romania  ROU  2017     3.9281     5.305071      15.801
# 455  Romania  ROU  2018     3.9787     5.168479      16.634
# 456  Romania  ROU  2019     3.8651     5.299655      15.962
# 457  Romania  ROU  2020     3.7154     5.222219      16.228
#
#      Renewable per capita  Solar Generation  Wind Generation  \
# 0                  95.341          0.011941         0.175500
# 1                 101.444          0.014960         0.415580
# 2                 101.457          0.017871         0.443584
# 3                  97.575          0.021329         0.535599
# 4                 101.360          0.025761         0.768281
# ..                    ...               ...              ...
# 453              1362.377          1.820000         6.590000
# 454              1235.883          1.856000         7.407000
# 455              1342.656          1.771000         6.322000
# 456              1271.911          1.778000         6.773000
# 457              1279.260          1.703000         6.955000
#
#      Hydro Generation  Geo Biomass Other
# 0           75.245817           2.269063
# 1           80.864115           2.335353
# 2           85.181468           2.286400
# 3           82.872601           2.622400
# 4           87.405469           2.978850
# ..                ...                ...
# 453         18.028000           0.531000
# 454         14.494000           0.525168
# 455         17.663900           0.437130
# 456         15.580921           0.504144
# 457         15.087386           0.575069
#
# [458 rows x 11 columns]

# %%
# Convert Df to CSV
final_df.to_csv('Resources/final.csv')
